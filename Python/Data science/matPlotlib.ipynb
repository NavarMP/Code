# %%
name = ['hashir', 'hadi', 'navar', 'asif']
mark = [10, 5, 50, 60]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot (name, mark, marker='.')
plt.xlabel ("Name")
plt.ylabel ("Mark")
plt.show()

# %%
name = ['hadi', 'hashir', 'NavarMP', 'Asif']
mark = [49, 34, 28, 60]
colors = ['#a4133c', '#ff4d6d','#ff8fa3', '#590d22']
plt.bar (name, mark, color = colors, width = 0.5)
plt.grid(color = '#121212')

plt.show()

# %%
plt.scatter (name, mark, marker = ',')

# %%
list = [67, 45, 20, 12]
name = ['Hashir', 'Hadi', 'Navar', 'Asif']
colors = ['#a4133c', '#ff4d6d','#ff8fa3', '#590d22']
plt.pie (list, labels = name, colors=colors)
plt.legend()

# %%
from pandas import read_excel
data = read_excel ('mark.xlsx')
data
# Out:
#    Roll no.    Name  Chemistry  Physics  Maths  Total
# 0         1  Hashir         43       87     20    150
# 1         2   Navar         23       87     45    155
# 2         3    Asif         53       68     24    145
# 3         4  Shadil         56       57     36    149
# 4         5    Hadi         21       33     78    132

# %%
data.plot()
# Out:
# <Axes: >

# %%
data.plot(x = "Physics", y = "Total", marker = '.')
plt.xlabel ("name")
plt.ylabel("total")
plt.grid()
