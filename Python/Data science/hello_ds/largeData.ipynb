# %%
import pandas as pd

# %%
data = pd.read_excel ("stressdata.xlsx")

# %%
data.head()
# Out:
#    gender  feel d0wn   age  0ver reacting  feel bad y0ur self  tired  \
# 0       1          0  30.0              0                   0      0
# 1       1          0  45.0              0                   1      0
# 2       1          1  20.0              1                   1      1
# 3       0          1  52.0              0                   0      0
# 4       1          2  45.0              0                   0      0
#
#    interest  th0ught 0f death       result
# 0         1                 1   depression
# 1         0                 1      anxiety
# 2         1                 0       normal
# 3         0                 0  frustration
# 4         1                 1   depression

# %%
# 8 attributes and 1 target
feat = data.iloc [:,0:8]
feat
# Out:
#      gender  feel d0wn   age  0ver reacting  feel bad y0ur self  tired  \
# 0         1          0  30.0              0                   0      0
# 1         1          0  45.0              0                   1      0
# 2         1          1  20.0              1                   1      1
# 3         0          1  52.0              0                   0      0
# 4         1          2  45.0              0                   0      0
# ..      ...        ...   ...            ...                 ...    ...
# 994       0          1  26.0              1                   1      1
# 995       0          2  48.0              0                   0      0
# 996       0          0  58.0              0                   0      0
# 997       0          1  26.0              1                   1      1
# 998       0          2  59.0              0                   0      0
#
#      interest  th0ught 0f death
# 0           1                 1
# 1           0                 1
# ...
